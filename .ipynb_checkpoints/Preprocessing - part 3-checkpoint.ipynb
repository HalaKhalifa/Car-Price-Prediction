# %% [markdown]
# # Car Listings Preprocessing

# %% [markdown]
# ## Goal:
# ##### 🔻 Process the cars DataFrame to prepare it for analysis.
#
# ## Steps:
#     ▼ Outliers Detecting for the column with NaN values
#     ▼ Outliers and missing values handling for these columns
#     ▼ Handling the outilers on whole dataset
#     ▼ save new df
#     ▼ EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
import arabic_reshaper
from bidi.algorithm import get_display

# %%
pd.set_option("display.max_columns", None)
df = pd.read_csv('csv_files/car_df.csv')
df
# Out:
#         Make   Price  Color Fuel Type Car Origin Car License  \
# 0        كيا   44000   أسود     بنزين      خصوصي    فلسطينية
# 1     هونداي   58000    فضي     بنزين      خصوصي    فلسطينية
# 2       بيجو   40000   أسود     بنزين      خصوصي    فلسطينية
# 3      سكودا   70000   أزرق      ديزل      خصوصي    فلسطينية
# 4     سوبارو   33000  رصاصي     بنزين      خصوصي    فلسطينية
# ...      ...     ...    ...       ...        ...         ...
# 6522    فيات   27000   أحمر     بنزين      خصوصي    فلسطينية
# 6523  هونداي  117000   أسود      ديزل      خصوصي    فلسطينية
# 6524  هونداي   67000    فضي     بنزين      خصوصي    فلسطينية
# 6525   سكودا   58000   أبيض     بنزين      خصوصي    فلسطينية
# 6526     سيت   65000   سكني     بنزين      خصوصي    فلسطينية
#
#      Transmission Type     Glass  Engine Power   Mileage   Payment Method  \
# 0            اوتوماتيك  الكتروني          1600  183000.0  إمكانية التقسيط
# 1            اوتوماتيك  الكتروني          1400   42000.0         نقدا فقط
# 2        نصف اوتوماتيك  الكتروني          2000   85000.0  إمكانية التقسيط
# 3                 عادي  الكتروني          1900   30000.0  إمكانية التقسيط
# 4                 عادي  الكتروني          1600       NaN         نقدا فقط
# ...                ...       ...           ...       ...              ...
# 6522              عادي      يدوي          1800   50000.0         نقدا فقط
# 6523         اوتوماتيك  الكتروني          2000     140.0         نقدا فقط
# 6524         اوتوماتيك  الكتروني          1400      40.0         نقدا فقط
# 6525         اوتوماتيك  الكتروني          1200   60000.0         نقدا فقط
# 6526              عادي  الكتروني          1400   82000.0  إمكانية التقسيط
#
#              Available  Previous Owners  Air Conditioner  Central Locking  \
# 0            للبيع فقط              1.0                1                1
# 1     للبيع أو التبديل              1.0                1                1
# 2            للبيع فقط              2.0                1                1
# 3     للبيع أو التبديل              3.0                1                1
# 4            للبيع فقط              NaN                1                1
# ...                ...              ...              ...              ...
# 6522         للبيع فقط              NaN                0                0
# 6523         للبيع فقط              NaN                1                1
# 6524         للبيع فقط              1.0                1                1
# 6525  للبيع أو التبديل              2.0                1                1
# 6526         للبيع فقط              1.0                1                1
#
#       Alarm System  CD Player  Sunroof  Alloy Wheels  Leather Seats  Airbag  \
# 0                1          1        0             0              1       1
# 1                1          0        0             1              1       1
# 2                1          1        1             1              1       1
# 3                1          1        0             1              1       1
# 4                1          1        0             1              0       1
# ...            ...        ...      ...           ...            ...     ...
# 6522             0          1        0             0              1       0
# 6523             1          0        1             1              1       1
# 6524             1          1        0             1              1       1
# 6525             1          1        0             1              0       1
# 6526             1          0        0             1              1       1
#
#       Passenger Count  age
# 0                 NaN   15
# 1                 4.0   10
# 2                 4.0   10
# 3                 4.0   13
# 4                 4.0   24
# ...               ...  ...
# 6522              NaN   50
# 6523              6.0    7
# 6524              4.0    6
# 6525              4.0    8
# 6526              NaN    7
#
# [6527 rows x 23 columns]

# %%
df[df.columns[df.isna().any()]].isna().sum()
# Out:
# Mileage            1782
# Previous Owners    1345
# Passenger Count     451
# dtype: int64

# %% [markdown]
# ##### Passenger Count

# %%
df['Passenger Count'].describe()
# Out:
# count    6076.000000
# mean        4.257406
# std         1.603875
# min         1.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max       104.000000
# Name: Passenger Count, dtype: float64

# %% [markdown]
# All values are on the normal range but the max is to much large , it might be an outlier

# %%
df.loc[df['Passenger Count'].idxmax()]
# Out:
# Make                             فورد
# Price                           68000
# Color                             بني
# Fuel Type                       بنزين
# Car Origin                      خصوصي
# Car License                  فلسطينية
# Transmission Type           اوتوماتيك
# Glass                        الكتروني
# Engine Power                     1600
# Mileage                       78000.0
# Payment Method        إمكانية التقسيط
# Available            للبيع أو التبديل
# Previous Owners                   0.0
# Air Conditioner                     1
# Central Locking                     1
# Alarm System                        1
# CD Player                           1
# Sunroof                             1
# Alloy Wheels                        1
# Leather Seats                       0
# Airbag                              1
# Passenger Count                 104.0
# age                                 9
# Name: 4229, dtype: object

# %% [markdown]
# Trying to find similar sample

# %%
df[(df['Make'] == 'فورد') & (df['Price'] == 68000) & (df['Fuel Type'] == 'بنزين')]
# Out:
#       Make  Price Color Fuel Type Car Origin Car License Transmission Type  \
# 3237  فورد  68000   فضي     بنزين      خصوصي    فلسطينية         اوتوماتيك
# 4229  فورد  68000   بني     بنزين      خصوصي    فلسطينية         اوتوماتيك
#
#          Glass  Engine Power  Mileage   Payment Method         Available  \
# 3237  الكتروني          2000  89000.0         نقدا فقط  للبيع أو التبديل
# 4229  الكتروني          1600  78000.0  إمكانية التقسيط  للبيع أو التبديل
#
#       Previous Owners  Air Conditioner  Central Locking  Alarm System  \
# 3237              NaN                1                1             1
# 4229              0.0                1                1             1
#
#       CD Player  Sunroof  Alloy Wheels  Leather Seats  Airbag  \
# 3237          1        1             1              1       1
# 4229          1        1             1              0       1
#
#       Passenger Count  age
# 3237              4.0   11
# 4229            104.0    9

# %% [markdown]
# The row have a lot of similarities so we can replace the value of '104' with '4'

# %%
df.at[4229, 'Passenger Count'] = df.at[3237, 'Passenger Count']

# %%
df['Passenger Count'].describe()
# Out:
# count    6076.000000
# mean        4.240948
# std         0.966709
# min         1.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max        22.000000
# Name: Passenger Count, dtype: float64

# %%
df['Passenger Count']= df['Passenger Count'].fillna(df['Passenger Count'].mode().iloc[-1])
df['Passenger Count'] = df['Passenger Count'].astype(int)

# %%
df[df.columns[df.isna().any()]].isna().sum()
# Out:
# Mileage            1782
# Previous Owners    1345
# dtype: int64

# %% [markdown]
# ##### Mileage

# %%
df['Mileage'].describe()
# Out:
# count    4.745000e+03
# mean     1.265937e+18
# std      8.720273e+19
# min      0.000000e+00
# 25%      1.070000e+04
# 50%      7.000000e+04
# 75%      1.350000e+05
# max      6.006870e+21
# Name: Mileage, dtype: float64

# %% [markdown]
# Mean, std, max have high values might indicate errors | outliers in the data.

# %%
sns.boxplot(x=df['Mileage'],color='g')
plt.show()

# %%
Q1 = df['Mileage'].quantile(0.25)
Q3 = df['Mileage'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['Mileage'] < Q1 - 1.5 * IQR) | (df['Mileage'] > Q3 + 1.5 * IQR)

df_impute = df.copy()
df_impute.loc[outliers, 'Mileage'] = np.nan
zero_mileage = (df_impute['Mileage'] == 0) & (df_impute['age'] > 0) # determining which cars are used & have a Mileage equal to zero
df_impute.loc[zero_mileage, 'Mileage'] = np.nan

imputer = KNNImputer(n_neighbors=5)
df_imputed_values = imputer.fit_transform(df_impute[['Mileage', 'age']])
df.loc[:, ['Mileage', 'age']] = df_imputed_values

# %%
sns.boxplot(x=df['Mileage'],color='g')
plt.show()

# %% [markdown]
# we can consider the least outliers as high value of mileage

# %%
df['Mileage'].describe()
# Out:
# count      6527.000000
# mean      91627.576344
# std       63728.923024
# min           1.000000
# 25%       41238.200000
# 50%       86627.600000
# 75%      135000.000000
# max      320000.000000
# Name: Mileage, dtype: float64

# %%
df[df.columns[df.isna().any()]].isna().sum()
# Out:
# Previous Owners    1345
# dtype: int64

# %% [markdown]
# ##### Previous Owners

# %%
df['Previous Owners'].describe()
# Out:
# count    5182.000000
# mean        2.168468
# std         1.975429
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        19.000000
# Name: Previous Owners, dtype: float64

# %%
sns.boxplot(x=df['Previous Owners'],color='g')
plt.show()

# %%
df['Previous Owners'] = df.groupby(['Car Origin', 'age'])['Previous Owners'].transform(lambda x: x.fillna(x.mean()))

# %%
df[df.columns[df.isna().any()]].isna().sum()
# Out:
# Previous Owners    17
# dtype: int64

# %%
df['Previous Owners'].fillna(df['Previous Owners'].mode().iloc[0], inplace=True)
df['Previous Owners'] = df['Previous Owners'].astype(int)

# %%
sns.boxplot(x=df['Previous Owners'],color='g')
plt.show()

# %% [markdown]
# make sure that the outliers on the graph have an reasonable age

# %%
Q1 = df['Previous Owners'].quantile(0.25)
Q3 = df['Previous Owners'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['Previous Owners'] < Q1 - 1.5 * IQR) | (df['Previous Owners'] > Q3 + 1.5 * IQR)

df[outliers]['age'].unique()
# Out:
# array([39., 34., 50., 19., 13., 47., 40., 18., 25., 21., 17., 31., 38.,
#        10., 28., 15., 41., 37., 26., 16., 36., 23., 33., 44., 35., 22.,
#        30., 24., 14., 12., 29., 43., 32., 27., 11., 20.])

# %% [markdown]
# It's normal that cars that have these numbers of years have a lot of previous owners so we will not change them

# %%
df.isna().any().sum()
# Out:
# 0

# %% [markdown]
# ### There's no missing values on the DataFrame now

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6527 entries, 0 to 6526
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               6527 non-null   object
#  1   Price              6527 non-null   int64
#  2   Color              6527 non-null   object
#  3   Fuel Type          6527 non-null   object
#  4   Car Origin         6527 non-null   object
#  5   Car License        6527 non-null   object
#  6   Transmission Type  6527 non-null   object
#  7   Glass              6527 non-null   object
#  8   Engine Power       6527 non-null   int64
#  9   Mileage            6527 non-null   float64
#  10  Payment Method     6527 non-null   object
#  11  Available          6527 non-null   object
#  12  Previous Owners    6527 non-null   int64
#  13  Air Conditioner    6527 non-null   int64
#  14  Central Locking    6527 non-null   int64
#  15  Alarm System       6527 non-null   int64
#  16  CD Player          6527 non-null   int64
#  17  Sunroof            6527 non-null   int64
#  18  Alloy Wheels       6527 non-null   int64
#  19  Leather Seats      6527 non-null   int64
#  20  Airbag             6527 non-null   int64
#  21  Passenger Count    6527 non-null   int64
#  22  age                6527 non-null   float64
# dtypes: float64(2), int64(12), object(9)
# memory usage: 1.1+ MB

# %%
for feature in df:
    print(f'{feature}:{df[feature].unique()}\n')
# Out:
# Make:['كيا' 'هونداي' 'بيجو' 'سكودا' 'سوبارو' 'سيت' 'اودي' 'فولكسفاجن' 'Dodge'
#  'مرسيدس' 'اوبل' 'شفروليه' 'فورد' 'فولفو' 'ستروين' 'جييب' 'تويوتا'
#  'ايسوزو' 'رينو' 'مازدا' 'فيات' 'بي' 'دايو' 'أفيكو' 'الفا' 'ميتسوبيشي'
#  'سانغ' 'دراجة' 'شاحنة' 'جي' 'هوندا' 'نيسان' 'داف' 'لاندروفر' 'روفر'
#  'داتشيا' 'كاديلاك' 'باص' 'سوزوكي' 'ديهاتسو' 'جاجوار']
#
# Price:[ 44000  58000  40000  70000  33000  78000  18000  30000  60000 125000
#   25000  32000  42000  39500 155000  23000  95000 175000  65300  13000
#   90000  85000  10000  36500  63000  47000  48000  98000  50000 115000
#   27000  24000  35000  86000  19000  68000  39000  45000  56000 100000
#  230000 110000  62000  38000  75000 120000  83000 109999  37000 350000
#  170000  65000  80000  20000  44999 113000  55000   5000  97000  69000
#   41000  89000   6000  72000  75500 107000   9500 163500  62500  49000
#   43500  43000  79000  17000 117000  79500 162000   2500  14000  12000
#  153000  26500  92000 145000  64000 138000 105000 270000  54000  28500
#  135000 118000  19500  59000  81000  57000 124000  99999 275000   7000
#    8500  94000 180000  16000  46000  93000 130000  61000 195000  11000
#   28000 285000  54500  77000  74000   9000  83500 104000  71000 104999
#  150000 143000  66000  82000  31000 290000 169000 360000  84000 190000
#  112000  15000  87000  21000 146000  76000  35500 144999  73000  12345
#   51000  39999  67000  52000  36000  74500 850000 123000   8000  26000
#  160000  44500  47500 200000  95500 209999 139000  53000  89500   1111
#   58999 134000  89900  22500 147000  88000 680000 117500 250000 240000
#  245000 165000  38500 220000 129000  49900  22000  88500 157000 225000
#   29000 102000  48500 132000  97999  35200 108000 149999 205000 140000
#  119000 139999  63999 340000  34000  13500  59999  99000   4700   2700
#   69999 999999 185000  27500   1700  39900 129900   2000 103000  69900
#    4500  68500 459000 258000  77500  20500  18500 142000 144000  56500
#  128000  99900 215000  41999  31999   2800 210000   1500  15500 148000
#   98765 420000  37500 249000 345000  45200  32500  74999  69500 116000
#   16800 109000 133000 122000  73900  65999  89999 127000  47900 137000
#  370000  46499 660000  72999 239000   2300   4000   6500  73500 320000
#   81900 115115  55999  91999 173999 172000 158000 114999  34500  10500
#  114000 156000   5500  98999 100005  53999  45500  96000  11500  49500
#    7500 265000  75999 119999  16500  59500 267000  58500 179000 330000
#  249999 115500  46500 630000  63500  73999  79900 103999   1200 152000
#  127999   3300 143999 260000  59900   7300 159000  82999 490000 385000
#  178000   3800 106000 133500  33500  85999 126000 189000   5700 439999
#   31500 164999 163000 127500  25500  77999  51500  46999  42500 280000
#   66500   3500 125500  90001  40500  11111  52500  79999   2200 550000
#  219000   3200 750000 223000  41500 149000 136000  50500  49999  48200
#   67500  94500 131000  74900 135999 114900 167000  82500   1900   7200
#  139500  29990  66999  57500  14500   4800  67100 123500 192000 173000
#   64900  63100   2600 181500 310000 102999  83999  12500 109900 235000
#  114500  59238  17500  35400  47999  24500  52999 121000 141000 450000
#   66666  64500 228000  54900  35555   3000  93500   1300 134999  43900
#    9900  42999 168000   3600  12600  29500   5200  26999 700000  11300
#   78500  86800 123999  76900   4200  58900 123456 880000 218000  86999
#   88999  34900  17800  24999 126999 184999  84999 480000 123400 106999
#   90900 129999  93200 188000 299999  71990 238000  61500 106500   2100
#  173500  81999 116999  46600   1800  18999  51900 135500 107999 300000
#  570000  91000  44900  29999  51999   1600 154000 196000  21500  15238
#  600000 176000]
#
# Color:['أسود' 'فضي' 'أزرق' 'رصاصي' 'أسود ميتالك' 'برتقالي' 'أحمر' 'أصفر' 'أبيض'
#  'ذهبي' 'سكني' 'فيراني' 'خمري' 'أبيض عاجي' 'رمادي' 'أخضر' 'عدة الوان'
#  'بترولي' 'كحلي' 'زيتي' 'أزرق سماوي' 'بيج' 'بني' 'كرميدي' 'بنفسجي' 'جيشي']
#
# Fuel Type:['بنزين' 'ديزل' 'هايبرد' 'كهرباء']
#
# Car Origin:['خصوصي' 'عمومي' 'تأجير' 'حكومي' 'تجاري' 'تدريب سياقة']
#
# Car License:['فلسطينية' 'نمرة صفراء']
#
# Transmission Type:['اوتوماتيك' 'نصف اوتوماتيك' 'عادي']
#
# Glass:['الكتروني' 'يدوي']
#
# Engine Power:[1600 1400 2000 1900 1200 6700 2500 2200 1800 1690 2800 3000 1500  999
#  1250 3100 1000 2400 2300 3600 3700 1300  230 2900 1190  250 3200  200
#  1700 1150 6500 7777 6000  120 1100 2700  903 3500  390 2850 1995  800
#   240 1450 1009 1108 1595  900  180 1605 1350 1989 2600 4600 2150 6600
#   220  125 5000 1495 4000 1850 2996 2250  210 1235 1234 4200 4800 1990
#   905  290 1240 1006 3300  280  140 4500  106  270  321  480 1999 2100
# Air Conditioner:[1 0]
#
# Central Locking:[1 0]
#
# Alarm System:[1 0]
#
# CD Player:[1 0]
#
# Sunroof:[0 1]
#
# Alloy Wheels:[0 1]
#
# Leather Seats:[1 0]
#
# Airbag:[1 0]
#
# Passenger Count:[ 4  5  2  8  1  6  7  3  9 22]
#
# age:[15. 10. 13. 24.  6. 38. 44.  8. 22. 16. 18.  7. 23. 25.  9. 26. 39. 14.
#  17. 20. 37. 12.  5. 11. 21.  4. 40. 32. 41.  2. 29. 28. 35. 36. 31.  3.
#  19. 34. 50. 30. 47. 33. 27. 42. 55. 51. 43. 49. 45.  1. 48. 46. 53. 56.]

# %% [markdown]
# Small detail to change : 'Dodge' => 'دودج' on make column

# %%
df['Make'].replace({'Dodge': 'دودج'}, inplace=True)

# %%
df.to_csv('csv_files/result.csv', index=False)

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# We Already start this step on the previous parts by :
# - Drop 'Addition' & 'Drive Type' columns
# - Create a new column called 'age' using 'year', and then drop 'year' column
# - we can add the column of 'Mileage/Year' from the mileage & age columns

# %%
df['Mileage/Year'] = np.where(df['age'] != 0, df['Mileage'] / df['age'], np.nan)
df['Mileage/Year'] = df['Mileage/Year'].round(2)

# %%
df
# Out:
#         Make   Price  Color Fuel Type Car Origin Car License  \
# 0        كيا   44000   أسود     بنزين      خصوصي    فلسطينية
# 1     هونداي   58000    فضي     بنزين      خصوصي    فلسطينية
# 2       بيجو   40000   أسود     بنزين      خصوصي    فلسطينية
# 3      سكودا   70000   أزرق      ديزل      خصوصي    فلسطينية
# 4     سوبارو   33000  رصاصي     بنزين      خصوصي    فلسطينية
# ...      ...     ...    ...       ...        ...         ...
# 6522    فيات   27000   أحمر     بنزين      خصوصي    فلسطينية
# 6523  هونداي  117000   أسود      ديزل      خصوصي    فلسطينية
# 6524  هونداي   67000    فضي     بنزين      خصوصي    فلسطينية
# 6525   سكودا   58000   أبيض     بنزين      خصوصي    فلسطينية
# 6526     سيت   65000   سكني     بنزين      خصوصي    فلسطينية
#
#      Transmission Type     Glass  Engine Power   Mileage   Payment Method  \
# 0            اوتوماتيك  الكتروني          1600  183000.0  إمكانية التقسيط
# 1            اوتوماتيك  الكتروني          1400   42000.0         نقدا فقط
# 2        نصف اوتوماتيك  الكتروني          2000   85000.0  إمكانية التقسيط
# 3                 عادي  الكتروني          1900   30000.0  إمكانية التقسيط
# 4                 عادي  الكتروني          1600   41238.2         نقدا فقط
# ...                ...       ...           ...       ...              ...
# 6522              عادي      يدوي          1800   50000.0         نقدا فقط
# 6523         اوتوماتيك  الكتروني          2000     140.0         نقدا فقط
# 6524         اوتوماتيك  الكتروني          1400      40.0         نقدا فقط
# 6525         اوتوماتيك  الكتروني          1200   60000.0         نقدا فقط
# 6526              عادي  الكتروني          1400   82000.0  إمكانية التقسيط
#
#              Available  Previous Owners  Air Conditioner  Central Locking  \
# 0            للبيع فقط                1                1                1
# 1     للبيع أو التبديل                1                1                1
# 2            للبيع فقط                2                1                1
# 3     للبيع أو التبديل                3                1                1
# 4            للبيع فقط                2                1                1
# ...                ...              ...              ...              ...
# 6522         للبيع فقط                7                0                0
# 6523         للبيع فقط                1                1                1
# 6524         للبيع فقط                1                1                1
# 6525  للبيع أو التبديل                2                1                1
# 6526         للبيع فقط                1                1                1
#
#       Alarm System  CD Player  Sunroof  Alloy Wheels  Leather Seats  Airbag  \
# 0                1          1        0             0              1       1
# 1                1          0        0             1              1       1
# 2                1          1        1             1              1       1
# 3                1          1        0             1              1       1
# 4                1          1        0             1              0       1
# ...            ...        ...      ...           ...            ...     ...
# 6522             0          1        0             0              1       0
# 6523             1          0        1             1              1       1
# 6524             1          1        0             1              1       1
# 6525             1          1        0             1              0       1
# 6526             1          0        0             1              1       1
#
#       Passenger Count   age  Mileage/Year
# 0                   4  15.0      12200.00
# 1                   4  10.0       4200.00
# 2                   4  10.0       8500.00
# 3                   4  13.0       2307.69
# 4                   4  24.0       1718.26
# ...               ...   ...           ...
# 6522                4  50.0       1000.00
# 6523                6   7.0         20.00
# 6524                4   6.0          6.67
# 6525                4   8.0       7500.00
# 6526                4   7.0      11714.29
#
# [6527 rows x 24 columns]

# %%
df.corr()
# Out:
#                     Price  Engine Power   Mileage  Previous Owners  \
# Price            1.000000      0.231600 -0.072708        -0.319212
# Engine Power     0.231600      1.000000  0.120335         0.017775
# Mileage         -0.072708      0.120335  1.000000         0.102215
# Previous Owners -0.319212      0.017775  0.102215         1.000000
# Air Conditioner  0.235373      0.032058  0.035769        -0.281543
# Central Locking  0.212864      0.026027  0.023015        -0.244349
# Alarm System     0.218042      0.074331 -0.047172        -0.188861
# CD Player        0.119167      0.079532  0.023640        -0.071285
# Sunroof          0.297950      0.215490 -0.018643        -0.069374
# Alloy Wheels     0.194235      0.048004 -0.009337        -0.087397
# Leather Seats    0.229781      0.157693 -0.049885        -0.101389
# Airbag           0.239801      0.034880  0.003997        -0.276312
# Passenger Count  0.140248      0.291451  0.016633        -0.029663
# age             -0.437462      0.095129  0.079655         0.605540
# Mileage/Year     0.211757      0.015621  0.630254        -0.212473
#
#                  Air Conditioner  Central Locking  Alarm System  CD Player  \
# Price                   0.235373         0.212864      0.218042   0.119167
# Engine Power            0.032058         0.026027      0.074331   0.079532
# Mileage                 0.035769         0.023015     -0.047172   0.023640
# Previous Owners        -0.281543        -0.244349     -0.188861  -0.071285
# Air Conditioner         1.000000         0.643269      0.444862   0.481854
# Central Locking         0.643269         1.000000      0.506364   0.458591
# Alarm System            0.444862         0.506364      1.000000   0.393553
# CD Player               0.481854         0.458591      0.393553   1.000000
# Sunroof                 0.179348         0.199682      0.206351   0.146497
# Alloy Wheels            0.385617         0.405883      0.344855   0.337289
# Leather Seats           0.257362         0.258490      0.310163   0.265079
# Airbag                  0.623726         0.650569      0.464987   0.433299
# Passenger Count         0.047927         0.047221      0.040885   0.030570
# age                    -0.477027        -0.406764     -0.302440  -0.154681
# Mileage/Year            0.173823         0.150440      0.085635   0.055956
#
#                   Sunroof  Alloy Wheels  Leather Seats    Airbag  \
# Price            0.297950      0.194235       0.229781  0.239801
# Engine Power     0.215490      0.048004       0.157693  0.034880
# Mileage         -0.018643     -0.009337      -0.049885  0.003997
# Previous Owners -0.069374     -0.087397      -0.101389 -0.276312
# Air Conditioner  0.179348      0.385617       0.257362  0.623726
# Central Locking  0.199682      0.405883       0.258490  0.650569
# Alarm System     0.206351      0.344855       0.310163  0.464987
# CD Player        0.146497      0.337289       0.265079  0.433299
# Sunroof          1.000000      0.275079       0.313890  0.184157
# Alloy Wheels     0.275079      1.000000       0.334932  0.401842
# Leather Seats    0.313890      0.334932       1.000000  0.270708
# Airbag           0.184157      0.401842       0.270708  1.000000
# Passenger Count  0.038472      0.027713       0.083314  0.072298
# age             -0.095705     -0.217030      -0.170189 -0.467199
# Mileage/Year     0.028437      0.091508       0.055849  0.166388
#
#                  Passenger Count       age  Mileage/Year
# Price                   0.140248 -0.437462      0.211757
# Engine Power            0.291451  0.095129      0.015621
# Mileage                 0.016633  0.079655      0.630254
# Previous Owners        -0.029663  0.605540     -0.212473
# Air Conditioner         0.047927 -0.477027      0.173823
# Central Locking         0.047221 -0.406764      0.150440
# Alarm System            0.040885 -0.302440      0.085635
# CD Player               0.030570 -0.154681      0.055956
# Sunroof                 0.038472 -0.095705      0.028437
# Alloy Wheels            0.027713 -0.217030      0.091508
# Leather Seats           0.083314 -0.170189      0.055849
# Airbag                  0.072298 -0.467199      0.166388
# Passenger Count         1.000000 -0.023880      0.032649
# age                    -0.023880  1.000000     -0.387111
# Mileage/Year            0.032649 -0.387111      1.000000

# %%
sns.heatmap(df.corr(),cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
df.hist(bins=100, figsize=(30,30),color='g')
plt.show()

# %%
important_numeric_features= df[['Price', 'Engine Power','Previous Owners', 'Mileage', 'age', 'Mileage/Year','Passenger Count']]
corr = important_numeric_features.corr()
sns.heatmap(corr, annot=True, cmap='Greens', fmt='.2f', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='Engine Power',y='Mileage',data=df,kind='hex',cmap='Greens',color='g')

# %%
sns.jointplot(x='Engine Power',y='Mileage',data=df,kind='reg',color='g')

# %%
sns.set_palette('Greens_d')
sns.pairplot(important_numeric_features)

# %%
merged_df = pd.merge(important_numeric_features, df[['Fuel Type']], left_index=True, right_index=True)
merged_df['Fuel Type Display'] = merged_df['Fuel Type'].apply(lambda x: get_display(arabic_reshaper.reshape(x)))
sns.pairplot(merged_df,hue='Fuel Type Display', palette='Greens_d')

# %%
df['Fuel Type']=df['Fuel Type'].apply(lambda x: get_display(arabic_reshaper.reshape(x)))
df['Make'] = df['Make'].apply(lambda x: get_display(arabic_reshaper.reshape(x)))
plt.figure(figsize=(30, 10))
sns.scatterplot(data=df, x="Make", y="Price", hue="Fuel Type", palette='Greens_d')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Price'>

# %%
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Price'>
